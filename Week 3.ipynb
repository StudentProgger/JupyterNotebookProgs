# %% [markdown]
# Data splitting: Dividing data into training, validation, and testing sets.

# %% [markdown]
# Data splitting: Dividing data into training, validation, and testing sets.

# %% [markdown]
# Data aggregation: Combining data at a higher level of granularity.

# %% [markdown]
# Handling time series data: Techniques for analyzing and preprocessing time-dependent data.

# %% [markdown]
# # Data Encoding

# %%
Quantitize the values:

# %% [markdown]
# String to integers

# %% [markdown]
# Date to days

# %% [markdown]
# Event numbers

# %% [markdown]
# To be able to use the data for mathematical machine learning algorithms

# %% [markdown]
# Approaches:

# %% [markdown]
# Map each string to a number

# %% [markdown]
# One-hot encoding

# %% [markdown]
# # Mapping to a value

# %% [markdown]
# For e.x., in NVD cve vulnerability dataset, you can map attack_complexity values to a number

# %%
import pandas as pd
df = pd.read_csv("nvd_cve_2022.csv")

# %%
df['attack_complexity'].unique()
# Out:
# array(['LOW', 'HIGH', nan], dtype=object)

# %%
#create a mapping dictionary
mapping={'HIGH' :1, 'LOW':2}

# %%
#Using the map method
df['attack_complexity']=df['attack_complexity'].map(mapping)

# %% [markdown]
# # One- hot encoding

# %% [markdown]
# One-hot encoding is a technique that is used to represent categorical variables as binary vectors.

# %% [markdown]
# One-hot encoding transforms each categorical variables into a new set of binary variables, where each variable represents a unique category  from the original variable. The process involves creating new binary variables (often called dummy variables) equal to the number of unique categories in the original variable.

# %% [markdown]
# One-hot encoding allows machine-learning algorithms to understand and efficiently use categorical data. It ensures the categorical variables are encoded in a format that captures the categorical information without imposing an arbitrary numerical order or magnitude on the categories.

# %% [markdown]
# * Here's an example to illustrate the concept. Let's say we have a categorical variable "Color" with three categories: Red, Green, and Blue.<br><br>
# * After applying one-hot encoding, the variable would be transformed into three binary variables: "Color_Red," "Color_Green," and "Color_Blue." <br><br>
# * The value of each binary variable indicates whether a specific category is present for each observation. <br><br>
# * For example, if an observation originally had the color "Red," the variables "Color_Red" would be 1, while "Color_Green" and "Color_Blue" would be 0.<br><br>

# %%
import pandas as py
#Sample data
data= {'Color': ['Red', 'Green', 'Blue', 'Green', 'Red']}
df= pd.DataFrame(data)

# %%
#Perform one-hot encoding
df_encoded=pd.get_dummies(df['Color'],prefix='Color',dtype=int)

# %%
df=pd.concat([df, df_encoded],axis=1)

# %%
print(df)
# Out:
#    Color  Color_Blue  Color_Green  Color_Red
# 0    Red           0            0          1
# 1  Green           0            1          0
# 2   Blue           1            0          0
# 3  Green           0            1          0
# 4    Red           0            0          1

# %%
cve_df=pd.read_csv("nvd_cve_2022.csv")

# %%
cve_df.head()
# Out:
#    Unnamed: 0             id  \
# 0           0  CVE-2022-0001
# 1           1  CVE-2022-0002
# 2           2  CVE-2022-0004
# 3           3  CVE-2022-0005
# 4           4  CVE-2022-0011
#
#                                              summary  \
# 0  ['Non-transparent sharing of branch predictor ...
# 1  ['Non-transparent sharing of branch predictor ...
# 2  ['Hardware debug modes and processor INIT sett...
# 3  ['Sensitive information accessible by physical...
# 4  ['PAN-OS software provides options to exclude ...
#
#                                       reference_data  \
# 0  ['https://www.intel.com/content/www/us/en/secu...
# 1  ['https://www.intel.com/content/www/us/en/secu...
# 2  ['https://www.intel.com/content/www/us/en/secu...
# 3  ['https://www.intel.com/content/www/us/en/secu...
# 4  ['https://security.paloaltonetworks.com/CVE-20...
#
#                                                 cpes  \
# 0  ['cpe:2.3:h:intel:celeron_j4005:-:*:*:*:*:*:*:...
# ...

# %% [markdown]
# # Exercise 1: Use one-hot to quantize the value of attack_complexity in nvd vulnerability dataset

# %% [markdown]
# # Fill in missing values with mean

# %% [markdown]
# Whenever the value of a variable(feature/column) in a dataset is not provided.

# %% [markdown]
# In the Pandas dataframe, it is usually represented as NAN or null.

# %% [markdown]
# How to handle missing values?
#
#     Drop the rows with missing values
#     May end up dropping a large number of rows (which in fact represent an object or an event)
#     dataframe.dropna()
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
#
#     Replace the missing values with an imputed value: an estimated value

# %% [markdown]
# # Mean/median Imputation
#
#     Replace missing values with the mean or median of the available values in the same column.
#     This approach assumes that the missing values are missing at random and that the mean or median is a representative value for the variable.
#     Find rows with missing values: missing_rows = cve_df[cve_df['column_name'].isnull()]
#     Fill in the missing values with mean mean_value = df['column_name'].mean() df['column_name'].fillna(mean_value, inplace=True)

# %%
cve_df['base_score'].mean()
# Out:
# 7.18466425088355

# %%
cve_df[cve_df['base_score'].isnull()]
# Out:
#        Unnamed: 0              id  \
# 116           116   CVE-2022-0177
# 163           163   CVE-2022-0227
# 194           194   CVE-2022-0259
# 258           258   CVE-2022-0329
# 417           417   CVE-2022-0498
# ...           ...             ...
# 22858       22858  CVE-2022-48313
# 22859       22859  CVE-2022-48314
# 22930       22930  CVE-2022-48437
# 22934       22934  CVE-2022-48468
# 22974       22974   CVE-2022-4893
#
#                                                  summary  \
# 116    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 163    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 194    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 258    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 417    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# ...                                                  ...
# 22858  ['The Bluetooth module has a vulnerability of ...
# 22859  ['The Bluetooth module has a vulnerability of ...
# ...

# %% [markdown]
# # Fill in missing values with mode (most frequent value)
#
# Replace missing categorical values with the mode (most frequent value) of the available values in the same column. This approach is suitable for categorical variables.
#
# Assuming you have a dataframe named 'df' and a column named 'column_name' with missing values
#
# Calculate the mode of the column mode_value = df['column_name'].mode()
#
# Fill missing values with the mode df['column_name'].fillna(mode_value, inplace=True)

# %%
#Exercise 2
cve_df['exploitability_score'].mode()
# Out:
# 0    3.9
# Name: exploitability_score, dtype: float64

# %%
#Find missing rows with missing value in column 'exploitability_score'
missing_rows=cve_df[cve_df['exploitability_score'].isnull()]

# %%
missing_rows
# Out:
#        Unnamed: 0              id  \
# 116           116   CVE-2022-0177
# 163           163   CVE-2022-0227
# 194           194   CVE-2022-0259
# 258           258   CVE-2022-0329
# 417           417   CVE-2022-0498
# ...           ...             ...
# 22858       22858  CVE-2022-48313
# 22859       22859  CVE-2022-48314
# 22930       22930  CVE-2022-48437
# 22934       22934  CVE-2022-48468
# 22974       22974   CVE-2022-4893
#
#                                                  summary  \
# 116    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 163    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 194    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 258    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 417    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# ...                                                  ...
# 22858  ['The Bluetooth module has a vulnerability of ...
# 22859  ['The Bluetooth module has a vulnerability of ...
# ...

# %% [markdown]
# # Missing values: KNN imputer

# %% [markdown]
# ![image.png](attachment:image.png)
#
#     Assuming you have a dataframe named 'df' and a column named 'column_name' with missing values
#
#     Create a copy of the dataframe df_imputed = df.copy()
#
#     Initialize the KNNImputer with the desired number of neighbors knn_imputer = KNNImputer(n_neighbors=5) # Adjust the number of neighbors as needed
#
#     Perform K-nearest neighbors imputation on the specific column df_imputed['column_name'] = knn_imputer.fit_transform(df[['column_name']])
#
#     Note: KNNImputer returns a numpy array, so we need to assign it back to the column in the dataframe
#
#     Print the imputed dataframe print(df_imputed)

# %%
import pandas as py
import numpy as py
from sklearn.impute import KNNImputer
knn_imputer=KNNImputer(n_neighbors=5) #Adjust the number of neighbors as needed.

# %%
cve_df[cve_df['base_score'].isnull()]
# Out:
#        Unnamed: 0              id  \
# 116           116   CVE-2022-0177
# 163           163   CVE-2022-0227
# 194           194   CVE-2022-0259
# 258           258   CVE-2022-0329
# 417           417   CVE-2022-0498
# ...           ...             ...
# 22858       22858  CVE-2022-48313
# 22859       22859  CVE-2022-48314
# 22930       22930  CVE-2022-48437
# 22934       22934  CVE-2022-48468
# 22974       22974   CVE-2022-4893
#
#                                                  summary  \
# 116    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 163    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 194    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 258    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# 417    ['** REJECT ** DO NOT USE THIS CANDIDATE NUMBE...
# ...                                                  ...
# 22858  ['The Bluetooth module has a vulnerability of ...
# 22859  ['The Bluetooth module has a vulnerability of ...
# ...

# %% [markdown]
# # Missing values: Regressible Imputation:

# %% [markdown]
# Predict missing values using regression models based on other variables. Missing values are treated as the dependent variable, and the other variables are used as predictors to estimate the missing values.

# %% [markdown]
# # Other approaches

# %% [markdown]
# Hot-deck imputation: Replace missing values with values randomly selected from similar records or observations in the same dataset. This approach maintains the statistical properties of the original dataset.
# Multiple imputation: Generate multiple imputations by creating multiple plausible values for each missing entry. Multiple imputation takes into account the uncertainty associated with missing values and provides a range of plausible values for analysis.
# Domain-specific imputation: Use domain knowledge or expert input to impute missing values based on specific characteristics or patterns in the data.

# %%
data={
    'A': [1,2,3,4, None,6,7,8, None, 10],
    'B':[2,4,None,8,10,12,None,16,18,20],
    'C':[3,6,9,None,15,18,21, None, 27, 30],
    'D':[4,None,12,16,20,24,28,32,36, None]
}
df=pd.DataFrame(data)
df
# Out:
#       A     B     C     D
# 0   1.0   2.0   3.0   4.0
# 1   2.0   4.0   6.0   NaN
# 2   3.0   NaN   9.0  12.0
# 3   4.0   8.0   NaN  16.0
# 4   NaN  10.0  15.0  20.0
# 5   6.0  12.0  18.0  24.0
# 6   7.0   NaN  21.0  28.0
# 7   8.0  16.0   NaN  32.0
# 8   NaN  18.0  27.0  36.0
# 9  10.0  20.0  30.0   NaN

# %%
import pandas as py
pd.options.mode.copy_on_write=True
from sklearn.linear_model import LinearRegression
# Create a sample dataframe
data = {
    'A': [1, 2, 3, 4, None, 6, 7, 8, None, 10],
    'B': [2, 4, None, 8, 10, 12, None, 16, 18, 20],
    'C': [3, 6, 9, None, 15, 18, 21, None, 27, 30],
    'D': [4, None, 12, 16, 20, 24, 28, 32, 36, None]
}
df = pd.DataFrame(data)
#Perform regression imputation for column 'D' using columns 'A', 'B', 'C',  as predictors
target_variable='D'
predictor_variables=['A','B','C']
#Split the dataframe into 2 parts: one with missing valuesn and one without missing values
df_missing=df[df[target_variable].isnull()]
df_not_missing=df[df[target_variable].notnull()]
#Prepare the training data
X_train= df_not_missing[predictor_variables]
Y_train=df_not_missing[target_variable]

#Fill missing values in predictor variables
X_train.fillna(X_train.mean(), inplace=True)
#Train the regression model
model=LinearRegression()
model.fit(X_train, Y_train)

#Predict the missing values using the trained model
X_test=df_missing[predictor_variables]
y_pred=model.predict(X_test)
#Fill in the missing values in the dataframe
df.loc[df[target_variable].isnull(), target_variable] = y_pred

# %%
df
# Out:
#       A     B     C          D
# 0   1.0   2.0   3.0   4.000000
# 1   2.0   4.0   6.0   5.955769
# 2   3.0   NaN   9.0  12.000000
# 3   4.0   8.0   NaN  16.000000
# 4   NaN  10.0  15.0  20.000000
# 5   6.0  12.0  18.0  24.000000
# 6   7.0   NaN  21.0  28.000000
# 7   8.0  16.0   NaN  32.000000
# 8   NaN  18.0  27.0  36.000000
# 9  10.0  20.0  30.0  45.051570

# %% [markdown]
# # Outliers

# %% [markdown]
# # Data preparation needs to take care of outliers

# %% [markdown]
# Outliers are observations that are noticeably different or inconsistent with the general pattern or distribution of the data.

# %% [markdown]
# These data points can be extremely high or low values or exhibit unusual behavior compared to the rest of the dataset.

# %% [markdown]
# Robust models: Certain machine learning algorithms are inherently robust to outliers, such as decision trees, random forests, and support vector machines with robust kernels.  These models are less affected by the presence of outliers in the data.

# %% [markdown]
# # user session dataset
#
# A JSONL (JSON Lines) file is a text file where each line represents a separate JSON object. JSONL is commonly used for storing and exchanging structured data in a compact and line-based format.
#
# Each line in a JSONL file contains a valid JSON object, which consists of key-value pairs represented in JSON (JavaScript Object Notation) format. Each line is self-contained and independent, allowing for easy parsing and processing of individual JSON objects.
#
# Here's an example of a JSONL file: {"name": "John", "age": 25, "city": "New York"} {"name": "Alice", "age": 30, "city": "London"} {"name": "Bob", "age": 35, "city": "Paris"}

# %%
import pandas as pd
session_df = pd.read_json('test.jsonl',lines=True)

# %%
session_df.head()
# Out:
#     session                                             events
# 0  12899779  [{'aid': 59625, 'ts': 1661724000278, 'type': '...
# 1  12899780  [{'aid': 1142000, 'ts': 1661724000378, 'type':...
# 2  12899781  [{'aid': 141736, 'ts': 1661724000559, 'type': ...
# 3  12899782  [{'aid': 1669402, 'ts': 1661724000568, 'type':...
# 4  12899783  [{'aid': 255297, 'ts': 1661724000572, 'type': ...

# %%
session_df.iloc[0]['events']
# Out:
# [{'aid': 59625, 'ts': 1661724000278, 'type': 'clicks'}]

# %%
#Apply json_normalize to extract keys 'aid','ts', and 'type' as separate columns
normalized_df = pd.json_normalize(session_df['events'])
new_df = pd.DataFrame(session_df['events'].apply(lambda x: x[0]).tolist())
session_df1 = pd.concat([session_df, new_df], axis=1)

# %%
session_df1.head()
# Out:
#     session                                             events      aid  \
# 0  12899779  [{'aid': 59625, 'ts': 1661724000278, 'type': '...    59625
# 1  12899780  [{'aid': 1142000, 'ts': 1661724000378, 'type':...  1142000
# 2  12899781  [{'aid': 141736, 'ts': 1661724000559, 'type': ...   141736
# 3  12899782  [{'aid': 1669402, 'ts': 1661724000568, 'type':...  1669402
# 4  12899783  [{'aid': 255297, 'ts': 1661724000572, 'type': ...   255297
#
#               ts    type
# 0  1661724000278  clicks
# 1  1661724000378  clicks
# 2  1661724000559  clicks
# 3  1661724000568  clicks
# 4  1661724000572  clicks

# %%
session_df1['timestamp'] = pd.to_datetime(session_df1['ts'], unit='ms')
session_df1.head()
# Out:
#     session                                             events      aid  \
# 0  12899779  [{'aid': 59625, 'ts': 1661724000278, 'type': '...    59625
# 1  12899780  [{'aid': 1142000, 'ts': 1661724000378, 'type':...  1142000
# 2  12899781  [{'aid': 141736, 'ts': 1661724000559, 'type': ...   141736
# 3  12899782  [{'aid': 1669402, 'ts': 1661724000568, 'type':...  1669402
# 4  12899783  [{'aid': 255297, 'ts': 1661724000572, 'type': ...   255297
#
#               ts    type               timestamp
# 0  1661724000278  clicks 2022-08-28 22:00:00.278
# 1  1661724000378  clicks 2022-08-28 22:00:00.378
# 2  1661724000559  clicks 2022-08-28 22:00:00.559
# 3  1661724000568  clicks 2022-08-28 22:00:00.568
# 4  1661724000572  clicks 2022-08-28 22:00:00.572

# %%
session_df1.shape
# Out:
# (1671803, 6)

# %%
# To findout number of session per user per day
session_df1.groupby(['aid','date'])['session'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # To findout number of session per user per day
# ----> 2 session_df1.groupby(['aid','date'])['session'].count()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %% [markdown]
# # Find Outlier by STD

# %% [markdown]
# The standard deviation is the average amount of variability in the dataset. It tells you, on average, how far each value lies from the mean.

# %% [markdown]
# Low-standard deviation means data are clustered around the mean, and high standard deviation indicates data are more spread out.

# %%
import numpy as np
#E.x. dataset
data = [2,4,6,8,10,12,14,16,10000]
#Finding outliers with a threshold of 2 standard deviations
threshold=2
mean=np.mean(data)
std=np.std(data)
cutoff=threshold * std
outliers=[x for x in data if (x < mean - cutoff) or (x > mean + cutoff)]

# %%
print("Mean:", mean)
print("STD:", std)
print("Outliers:", outliers)

# %% [markdown]
# # Local Factor Outliers

# %% [markdown]
# The Local Factor Outlier(LFO) algorithm measures the degree to what a data point stands out from it's local neighborhood, allowing the identification of outliers or anomalies in the dataset.
# The LOF algorithm provides a measure of the outlierness for each data point, allowing you to rank them based on their degree of deviation from the local density. Higher LOF values indicate stronger outliers, while LOF values close to 1 suggest that a data point is similar to it's neighbors.
# By applying the LOF algorithm to it's dataset. you can identify a anomalous datapoints that exhibit unusual patterns or behaviors compared to their local surroundings. This makes LOF a useful tool for anomaly detection and outlier analysis in various domains.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.neighbors import LocalOutlierFactor
#Assuming your DataFrame is named "session_group_df", and the column you want to analyze is named 'session'.
# Calculate mean and standard deviation.
session_group_df=session_df1.groupby(['aid','date']).count()
mean= np.mean(session_group_df['session'])
std= np.std(session_group_df['session'])
threshold = 5 #Number of standard deviations to consider as an outlier

# %%
#Fit the Local Outlier Model
lof_model= LocalOutlierFactor(contamination=0.01) #Contamination refers to the expected proportion of outliers.
outlier_scores= lof_model.fit_predict(session_group_df['session'].values.reshape(-1,1))

# %%
#Create the chart
plt.figure(figsize=(8,6))
plt.plot(session_group_df.index, session_group_df['session'], 'bo-', label='Data')

# %%
#Plot the outliers identified by LOF
outliers= session_group_df[outlier_scores == -1]
plt.plot(outliers.index, outliers['session'], 'ro', label='Outliers')

# %%
plt.xlabel('Index')
plt.ylabel('# of Sessions')
plt.title('Outliers based on Local Outlier Factor')
plt.legend()
plt.grid(True)

# %%
#Show the chart
plt.show()
